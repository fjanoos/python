# %% [markdown]
# # Test Jensen's

# %%
import scipy.stats as ss
ss.gamma.expect?

# %%
from pylab import *

# %matplotlib nbagg


a = 0.5
N = 10000
M = 10000

p = rand( N, 100 )
p = p/sum(p, axis=0)
assert np.allclose(p.sum(axis=0), 1 )

x = np.reshape( linspace(-10, 10, N), (-1,1) )

f = exp

fE = f( p * x ).sum(axis=0)
Ef = (p * f(x)).sum(axis=0)


plot( fE, Ef, '.' )


figure()
imshow(p)
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
fE.shape, Ef.shape
# Out:
# ((100,), (100,))

# %%
from pylab import *

# %matplotlib nbagg


a = 0.5
N = 10000

x = rand( N )
y = rand( N )

f = exp

fE = f(a*x + (1-a)*y )

plot( , a*f(a) + (1-a)*f(y), '.' )
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">
